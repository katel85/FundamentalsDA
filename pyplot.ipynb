# %% [markdown]
# # Overview of Matplotlib.pyplot Package
# ***

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
# - Create publication quality plots.
# - Make interactive figures that can zoom, pan, update.
# - Customize visual style and layout.
# - Export to many file formats .
# - Embed in JupyterLab and Graphical User Interfaces.
# - Use a rich array of third-party packages built on Matplotlib.
#
# **Pyplot** is an API (Application Programming Interface) for Python’s matplotlib that effectively makes matplotlib a viable open source alternative to MATLAB. Pyplot is mainly intended for interactive plots and simple cases of programmatic plot generation. [1]

# %% [markdown]
# ### Theory behind Matplotlib:
#
# ***

# %% [markdown]
# To understand how matplotlib works we should look at the history of Matplotlib. Matplotlib was originally developed by a neurobiologist named John D. Hunter in the early 2000s.
# His original inspiration for the project came from the popular MATLAB software. He wanted to emulate MATLAB’s plotting commands, but within Python, effectively combining the power of both Python and MATLAB.Unfortunately, John passed away in 2012. But now Matplotlib is a full-fledged community effort developed and maintained by a host of talented individuals.
#
# One area where Matplotlib draws inspiration from MATLAB is in its global import style. The Python concept of importing is not heavily used in MATLAB, meaning that most of MATLAB’s functions are readily available to the user at the top level.These functions can be called on their own, instead of on some object or a module alias. These functions all exist the submodule of matplotlib called pyplot.
#
# One important, big picture Matplotlib concept is its object hierarchy. In Matplotlib, a plot is a hierarchy of nested Python objects. A hierarchy means that there is a tree-like structure of Matplotlib objects underlying each plot.
#
# A Figure object is the outermost container for a Matplotlib plot. The Figure object contain multiple Axes objects. So, the Figure is the final graphic that may contain one or more Axes. The Axes represent an individual plot.

# %% [markdown]
# ### Matplotlib API Overview
# ***
#
# Matplotlib has two APIs to work with.
#
# **The pyplot interface.**
#
# Pyplot provides matplotlib with two key features:
#
# - A MATLAB-style interface, which allows those familiar with MATLAB to adopt Python more easily
#
# - Statefulness, which means that pyplot stores the state of an object when you first plot it. This is essential for use in the same loop or session state until plt.close() is encountered in the code. State can also be important when creating several plots continuously.
#
# **The Object-Oriented interface(OOI).**
#
# - At its core, Matplotlib is object-oriented. It is recommend directly working with the objects, if you need more control and customization of your plots.
#
# - In many cases you will create a Figure and one or more Axes using pyplot.subplots and from then on only work on these objects. However, it's also possible to create Figures explicitly.
#
# - To look more at the object oriented interface you could read more on [matplotlib.axes.Axes](https://matplotlib.org/stable/api/axes_api.html#matplotlib.axes.Axes) or [ matplotlib.figure.Figure](https://matplotlib.org/stable/api/figure_api.html#matplotlib.figure.Figure). In the Marplotlib API you can see many examples of plots using the OOI.
#
# **The Pylab Interface**
#
# - There is a third interface called pylab interface. It merges pyplot (for plotting) and NumPy (for mathematical functions) together in an environment closer to MATLAB.This is now considered bad practice. It was incorporated into iPython as a transition tool.The use of pylab is strongly discouraged[2,3,5]

# %% [markdown]
# ### Important Pyplot Commands when coding for plots using matplotlib.pyplot
#
# The  most common functions used in pyplot are below. By knowing the usage of these commands, you will be able to create pretty much any type of customization you want.[4]
#
#
# - **plt.figure()** – Set the properties of the figure canvas, like figsize, dpi etc.
# - **plt.subplot()** – Select the subplot to draw within the figure.
# - **plt.plot()** – Makes a line plot by default. Can make other types
# - **plt.subplots()** – Create and initialize the figure and axes. This outputs the figure and axis objects.
# - **plt.scatter(x,y)** – Draw a scatterplot of x and y
# - **plt.pie()** – Create a pie chart
# - **plt.hist()** – Create a histogram
# - **plt.hist2d()** – Create 2-D Histogram
# - **plt.bar()** – Create bar plot
# - **plt.text()** – Add text annotation inside the plot
# - **plt.colorbar()** – Add a colorbar. Used when color of dots in scatterplot is set based on a continuous numeric variable.
# - **plt.xlabel(), plt.ylabel()** – label the x and y axis
# - **plt.xlim(), plt.ylim()** – Set X and Y axis limits
# - **plt.title()** – Add current plot’s title
# - **plt.legend()** – Set the legend for current plot
# - **plt.suptitle()** – Apply a title for entire figure
# - **plt.tight_layout()** – Tightly arrange the subplots
# - **plt.xticks(), plt.yticks()** – Adjust the x and y axis ticks position and labels
# - **plt.gca(), plt.gcf()** – Get the current axis and figure
# - **plt.subplot2grid and plt.GridSpec** – Lets you draw complex layouts
# - **plt.show()** – Display the entire plot
# - **plt.rcParams.update()** – Update global plotting parameters

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# **Visulaization with Pyplot:**
#
# Generating visualization with Pyplot is very easy. The x-axis values ranges from 0-3 and the y-axis from 1-4. If we provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values.
#
# Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0,1,2,3] and y data are [1,2,3,4].

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('Numbers')
plt.show()

# %% [markdown]
# **State-machine interface:**
#
# Pyplot provides the state-machine interface to the underlying object-oriented plotting library. The state-machine implicitly and automatically creates figures and axes to achieve the desired plot. For example:

# %%
x = np.linspace(0, 5, 50)
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()
plt.show()

# %% [markdown]
# **Formatting the style of plot**
#
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot. The letters and symbols of the format string are from MATLAB.
# We can concatenate a color string with a line style string. The default format string is ‘b-‘, which is a solid blue line. For example, to plot the above line with blue asterics, we would issue the code below.The axis() command below takes a list of [xmin, xmax, ymin, ymax] and specifies the viewport of the axes.

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'b*')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# ### Code for Pyplot and Object Orientated Interface in Matplotlib:
#
# As can be seen from the plot below we have generated the exact same plot using two different matplotlib interfaces.[6]

# %%
x = np.linspace(0, 2, 20)

#Creating axes and figures explicitly by initializing objects for a figure. 
# We can call methods on them and therefore it is called as object-oriented.
fig, ax = plt.subplots()  
ax.plot(x, x, label='linear')  
ax.plot(x, x**2, label='quadratic')  
ax.step(x, x**3, label='cubic steps')  
ax.set_xlabel('x label')  
ax.set_ylabel('y label')  
ax.set_title("A simple plot using Object Oriented Style")  
ax.legend()  
ax.grid()

#Pyplot automatically creates and manages the figures and axes.
#The defined functions for plotting and pyplot api itself calculates to operate on figures.

plt.figure()
plt.plot(x, x, label='linear')  
plt.plot(x, x**2, label='quadratic')  
plt.step(x, x**3, label='cubic steps')  
plt.xlabel('x label')  
plt.ylabel('y label')  
plt.title("A simple plot using automatically created by pyplot")  
plt.legend()  
plt.grid()

# %% [markdown]
# # Three interesting plots types from the matplotlib.pyplot
#
#
# An in-depth explanation of three interesting plots from the matplotlib.pyplot
# Python package is required for this notebook. The three plots we will be looking at in detail are
#
# 1) The scatter plot
# 2) The histogram plot
# 3) The line plot

# %% [markdown]
# ## The Scatter Plot in the matplotlib.pyplot package
#
# ***
#
# Scatter plots are used to observe relationship between variables and uses dots to represent the relationship between them. The scatter() method in the matplotlib library is used to draw a scatter plot. Scatter plots are widely used to represent relationships among variables and how change in one affects the other.[7]
#
# The scatter() method takes in the following parameters:
# - x_axis_data- An array containing x-axis data
# - y_axis_data- An array containing y-axis data
# - s- marker size (can be scalar or array of size equal to size of x or y)
# - c- color of sequence of colors for markers
# - marker- marker style
# - cmap- cmap name
# - linewidths- width of marker border
# - edgecolor- marker border color
# - alpha- blending value, between 0 (transparent) and 1 (opaque)
#
#
# Except x_axis_data and y_axis_data all other parameters are optional and their default value is None.

# %% [markdown]
# Let's start with a a scatter plot using minimum code.
#
# You perform the following steps:
#
# - Create the data for the (x,y) points.
# - Plot the data using the plt.plot() function. The first argument is the iterable of x values. The second argument is the iterable of y values. The third argument is the style of the scatter points. If the style had not been included in the first figure code 'o' this code would have drawn a lineplot.
# - The second scatter plot below uses the same x and y variables but instead of using *plt.plt* I used *plt.scatter* and denoted the colour to use in the figure. If the hird argument had not been used we would have seen a line plot in the first cell of code.

# %%
x = [0, 1, 2, 3, 4, 5]
y = [1, 2, 4, 8, 16, 32]
plt.plot(x, y, 'o') 
plt.show()

# %%
x = [0, 1, 2, 3, 4, 5]
y = [1, 2, 4, 8, 16, 32]
plt.scatter(x, y, c='blue')
plt.show()

# %% [markdown]
# Now lets create a scatterplot that will use some more functions in the package such as labels,figsize,titles and legends.[8,9]
#
#
# Now, let us specify size to each of the points. To specify size to each of the markers, pass a list for named parameter s to scatter() function. Respective values from the s size list shall be applied to the markers drawn at points specified by x and y.
#
# In the following example, the size for markers is generated randomly using numpy.random. 25 values are generated for size, in the range (0, 25).We can set color to each of the marker in the scatter plot. Provide the list of colors as fourth parameter or named parameter c for scatter() function.
#
# Just for overview the first code cell below is in OOI style and the second is on the pyploy style.
# When doing this I didn't find a way to create 2 legends in the pyplot style. The aove statement that said you had more control and customization of your plot is true.

# %%
# Object Orientated Style
from numpy.random import default_rng
rng = default_rng(12345)

x = rng.integers(0, 25, 25)
y = rng.integers(0, 25, 25)
size = rng.integers(0, 25, 25)
color= rng.integers(0,25,25) 
fig, ax = plt.subplots()

#scatter plot
scatter = ax.scatter(x, y, c=color, s=size)
#plt.scatter(x, y, s = size, c= color)
# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Colours")
ax.add_artist(legend1)
# produce a legend with a cross section of sizes from the scatter
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
legend2 = ax.legend(handles, labels, loc="upper right", title="Sizes")

plt.show()

# %%
# Pyplot Interface Style
from numpy.random import default_rng
rng = default_rng(12345)
#data
x = rng.integers(0, 25, 25)
y = rng.integers(0, 25, 25)
#size
size = rng.integers(0, 25, 25)
#color
color = rng.integers(0, 25, 25)
plt.legend(*scatter.legend_elements(),
                    loc="lower left", title="Colours") 

handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
plt.legend(handles, labels, loc="upper right", title="Sizes")
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.08), ncol=3)
#scatter plot
plt.scatter(x, y, s = size, c = color)
 
plt.show()

# %% [markdown]
# **Scatterplot and Relationship Status**
#
# Scatterplots are used to observe relationships between two different variable so let's look at this some sample data. This scatter plot will look at the relationship between apples eaten per day and trips to the doctor per year using numpy for the arrays. As we can see from the scatterplot below it appears that the the more apples you eat the less visits you need to pay the doctor.

# %%
# Number of apples eaten per day (no-unit)
X = np.array([0,2,4,0,3,2,0])

# Doctors Visits per year
Y = np.array([4,1,0,3,1,1,5])

plt.scatter(X, Y)

plt.xlabel('Apples Daten Daily')
plt.ylabel('Doctors Visits Yearly')
plt.show()

# %% [markdown]
# **Looking at links between Groups**
#
# 1) Lets look at a scatter plot with three different data groups with height and weight measured. Each group is differenciated using the diffrernt colours. Code was adapted from[10]. We can see form this scatterplot that seems to be a linear relationship between height and weight.
#
# 2) The second plot looks at some randomly generated data with a colormap included to show how the color changes and the number increases.
#
# 3) The third plot looks at plotting the scatter with names and colors and plotting names in the legend to distinguish.[12]

# %%
weight1=[57,56,59,58,58,61,51,52,62,63]
height1=[121,131,125,128,126,127,145,118,129,135]

weight2=[61,69,62,65,64,66,63,65,68,61]
height2=[145,150,162,155,166,154,159,162,191,153]

weight3=[69,70,75,74,79,78,77,78,79,71]
height3=[191,195,188,155,187,196,201,212,234,200]

weight=np.concatenate((weight1,weight2,weight3))
height=np.concatenate((height1,height2,height3))

color_array = ['b'] * 10 + ['g'] * 10 + ['r']*10
plt.scatter(weight, height, marker=r'$\clubsuit$', c=color_array)

plt.xlabel('weight', fontsize=16)

plt.ylabel('height', fontsize=16)

plt.title('grouped scatter plot - height vs weight',fontsize=20)

plt.show()

# %%
# Simple Scatterplot with colored points[11]
x = range(50)
y = range(50) + rng.integers(0,30,50)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.scatter(x, y, c=y, cmap='Spectral')
plt.colorbar()
plt.title('Simple Scatter plot')
plt.xlabel('X - value')
plt.ylabel('Y - value')
plt.show()

# %%
# add a legend for each different point,
# %matplotlib inline
x1 = ([1,2,3], [4,2,3])
x2 = ([4,5,6], [4,5,6])
x3 = ([7,8,9,10], [7,8,9,10])
data = (x1, x2, x3)
colors = ("red", "green", "blue")
groups = ("monkey", "whale", "cat") 

for data, color, group in zip(data, colors, groups):
    x, y = data
    plt.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)
plt.legend(loc=2)
plt.figure()

# %% [markdown]
# ### Correlation with Scatter plot
# 1) If the value of y increases with the value of x, then we can say that the variables have a positive correlation.
#
# 2) If the value of y decreases with the value of x, then we can say that the variables have a negative correlation.
#
# 3) If the value of y changes randomly independent of x, then it is said to have a zero corelation.
#
# In the below graph, you can see that the blue line shows an positive correlation, the orange line shows a negative corealtion and the green dots show no relation with the x values(it changes randomly independently).

# %%
# Scatterplot and Correlations
# Data
x=rng.random(100)
y1= x*5 +9 
y2= -5*x
y3=rng.random(100)

# Plot
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.scatter(x, y1, label=f'y1 Correlation = {np.round(np.corrcoef(x,y1)[0,1], 2)}')
plt.scatter(x, y2, label=f'y2 Correlation = {np.round(np.corrcoef(x,y2)[0,1], 2)}')
plt.scatter(x, y3, label=f'y3 Correlation = {np.round(np.corrcoef(x,y3)[0,1], 2)}')

# Plot
plt.title('Scatterplot and Correlations')
plt.legend()
plt.show()

# %% [markdown]
# **Changing the Color and Marker to show different distributions:**
#
# Below is coded for the standard normal,chisqaure and poisson random distributions. We can disguish each each by ensuring the code has a different marker and colour for each.

# %%
#*Scatterplot of different distributions. Color and Shape of Points.*
rng = default_rng(12345)
x = np.arange(500)
y1 = np.random.standard_normal(500)
y2 = np.random.default_rng().chisquare(10,500)
y3 = np.random.poisson(5, 500)

#*Plot*
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.scatter(x,y1,color='blue', marker= '*', label='Standard Normal')
plt.scatter(x,y2,color= 'red', marker='v', label='Chi-Square')
plt.scatter(x,y3,color= 'green', marker='.', label='Poisson')


#*Decorate*
plt.title('Distributions: Color and Shape change')
plt.xlabel('X - value')
plt.ylabel('Y - value')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Using Text with scatterplots**
#
# Matplotlib scatter marker text – all points annotation
# If we want to annotate all points in the scatter plot, we have annotate() method in matplotlib[13]

# %%
# Define Data
x = [x for x in range(5)]
y = np.array([20,50,200,500,1000])
text = ["first", "second", "third", "fourth", "fifth"]
# Define scatter() function
plt.scatter(x, y)
# Annotate the point
for i in range(len(x)):
    plt.annotate(text[i], (x[i], y[i] + 0.2))
plt.show()

# %% [markdown]
# ## The Histogram  Plot
#
# ***

# %% [markdown]
# ### What is a histogram?
#
# A histogram is a chart that plots the distribution of a numeric variable’s values as a series of bars. Each bar typically covers a range of numeric values called a bin or class; a bar’s height indicates the frequency of data points with a value within the corresponding bin.[14,15,24]
#
# **Uses of Histogram Graph:**
# - Identification of Mode in a Dataset
# Without complex mathematical computations, one can easily identify the most common process outcome in a dataset. By visualizing the collected data on a histogram chart, the outcome with the highest frequency will easily stand out as the peak of the graph.
#
# - Identifying data structure
# One can easily spot trends in the data when reading a histogram chart. This can be helpful in making predictions, optimizing processes, and identifying possible issues.
#
# - Spotting deviations in data
# You can easily spot deviations in data when visualizing using a histogram compared to some other data visualization methods. This is very useful in cases where you are collecting data over time.
#
# Immediately there is a deviation in the data, the deviation is noticed on the histogram chart. This will easily help you let you inspect the data collection process and make amends if the deviation is caused by human error.
#
# **Disadvantages of a Histogram Graph**
# - It can only be used to visualize continuous data. Since the graphs are usually joined together, it will be incorrect to use a histogram to visualize discrete data. This can only be done using a bar chart.
#
# - Since data is grouped into different categories, histograms cannot read exact values. You cannot identify specific data points in the graph by merely reading the histogram chart.
#
# **Best practices for using a histogram**
#
# - Use a zero-valued baseline:
# Since the frequency of data in each bin is implied by the height of each bar, changing the baseline or introducing a gap in the scale will skew the perception of the distribution of data.
#
# - Choose an appropriate number of bins:
# Using wider bins where the density of the underlying data points is low reduces noise due to sampling randomness; using narrower bins where the density is high (so the signal drowns the noise) gives greater precision to the density estimation. Thus varying the bin-width within a histogram can be beneficial.[16]
#
# - Choose interpretable bin boundaries:
# Labels don’t need to be set for every bar, but having them between every few bars helps the reader keep track of value.

# %% [markdown]
# ### Basic Histogram Plotting in Matplotlib

# %% [markdown]
# The following list shows the parameters accepted by matplotlib.pyplot.hist() function[17]:
#
# **Attribute parameter**
#
# - x-array or sequence of array
#
# - bins-optional parameter contains integer or sequence or strings
#
# - density-optional parameter contains boolean values
#
# - range-optional parameter represents upper and lower range of bins
#
# - histtype-optional parameter used to create type of histogram [bar, barstacked, step, stepfilled], default is “bar”
#
# - align-optional parameter controls the plotting of histogram [left, right, mid]
#
# - weights-optional parameter contains array of weights having same dimensions as x
#
# - bottom-location of the basline of each bin
#
# - rwidth- optional parameter which is relative width of the bars with respect to bin width
#
# - color-optional parameter used to set color or sequence of color specs
#
# - label-optional parameter string or sequence of string to match with multiple datasets
#
# - log-optional parameter used to set histogram axis on log scale

# %% [markdown]
# **Basic Histogram Plotting**
#
# Let's start with some basic histogram plotting in the matplotlib.pyplot library.
#
# An array is created using numpy and assigned it to x. We are then drawing a python histogram using the hist function without any bins argument.
#
# The second image I used the same data but I added the bin number. The first bin number is 5 and the second bin number is 20. The data does look remarkably different depending on bin number.

# %%
# Creating dataset
x = np.array([4,7,9,34,5,67,85,32,4,5,21,7])
 
# Creating histogram
plt.hist(x)

plt.show()

# %%
x = np.array([4,7,9,34,5,67,85,32,4,5,21,7])
# using subplot function and creating plot one
plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.hist(x, bins=5, color='r')
plt.title('Bin No 5')
plt.xlabel('x-axis')
plt.ylabel('y-axis') 
# using subplot function and creating plot two
# row 1, column 2, count 2
plt.subplot(1, 2, 2) 
# g is gor green color
plt.hist(x,bins=20, color='g')
plt.title('Bin No 20')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
 
# space between the plots
plt.tight_layout()
 
# show plot
plt.show()

# %% [markdown]
# **Normal Distribution Histograms**
#
# Now we can create some histogram plots using the numpy random normal function to see a normal distribution histogram. function to generate some datasets.[18,19]

# %%
rng= default_rng(12345)
mu, sigma = 0, 0.1
mu1,sigma1= 0.3,0.1
s = np.random.default_rng().normal(mu, sigma, 10000)
t = np.random.default_rng().normal(mu1, sigma1, 10000)
count, bins, ignored = plt.hist(s, 30,color='g',edgecolor='w', density=True, alpha=0.8)
count, bins, ignored = plt.hist(t, 30,color='y',edgecolor='w', density=True, alpha=0.5)# using the alpha will create the shawdow in the overlay
plt.grid(axis='y',alpha=0.4)# alpha will amke the gridlines more transparent

# %% [markdown]
# **Plotting Different Distribution Types with a Histogram**
#
# Now lets plot two histograms side by side to see how they look. One will be a rng random distribution of numbers and the other will be a rng normal distribution.

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.subplot(1,2,1)
x = np.random.default_rng().uniform(4,3,1000)
y = np.random.default_rng().wald(4, 3, 1000)
plt.hist(x , bins=50) 
plt.title('Uniform Distribution ')
plt.subplot(1,2,2) 
plt.hist(y, bins=50) 
plt.title('Wald Distribution')
plt.tight_layout() 
plt.show()

# %% [markdown]
# **Using Text in Histograms**
#
# Below we look at a random normal geration of numbers representing the range in IQ using 100 as a mean and 15 as the SD.
# We can plot the text in the using pyplot text.[20]

# %%
# Fixing random state for reproducibility
rng= default_rng(12345)
mu, sigma = 100, 15
x = mu + sigma * np.random.standard_normal(10000)
# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)
plt.xlabel('IQ')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.xlim(40, 160)
plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %% [markdown]
# **Horizontal Orientation in a Histogram**
#
# Sometimes for interest ake it might be more aesthetically pleasing to look at a histogram with a different orientation as with the below histogram[21]

# %%
bmi_men=[31,18,40,15,18,19,26,28,21,22,23]
bmi_women=[17,41,30,19,24,21,16,40,35,19,18]

plt.xlabel("Total no of patients")
plt.ylabel("BMI Range")
plt.title("BMI analysis")

plt.hist([bmi_men,bmi_women],bins=10,rwidth=0.95,
         color=["green","orange"],label=["men","women"],orientation="horizontal"
        )
plt.legend()

# %% [markdown]
# **Histogram Annotate and Customisation**
#
# Below we have made an annotation for an important area in the histogram. If I were working with data and hthe histogram hit a certain level that was important annotation would be a good way to communicate this with the reader. Below we have used the code to draw an red line at the median age point.[21,22]

# %%
rng = np.random.default_rng(seed=12345)
y = np.random.default_rng().normal(0, 1, 6000)
plt.figure(figsize=(10,5)) # Plot size
plt.style.use('seaborn-whitegrid') # Style

# Building a histogram
n, bins, patches = plt.hist(y, bins=90, facecolor='#2ab0ff', edgecolor='#e0e0e0', linewidth=0.5, alpha=0.7)

# Changing properties of each bin
n = n.astype('int') # n should be integer, otherwise it wouldn't work properly

# Accessing each bin, changing color according to height
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))
    
# Pick one bin
patches[40].set_fc('red') # Color
patches[40].set_alpha(1) # Opacity

# Making annotation
plt.annotate('Something important here!', xy=(-0.5, 40), xytext=(2, 130), fontsize=10, arrowprops={'width':0.4,'headwidth':7,'color':'#333333'})

# Adding title and labels with custom font sizes
plt.title('Normal Distribution', fontsize=12)
plt.xlabel('Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10,5))
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]
bins = [i*8 for i in range(1,15)]
median_age = 29
color = 'r'
plt.axvline(median_age, color=color, label='Age Median')
plt.hist(ages, bins=bins, edgecolor='black')
#plt.annotate('Median Age', xy=(29, 3.5), xytext=(2, 8), fontsize=10, arrowprops={'width':0.4,'headwidth':7,'color':'#333333'})
plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## The Line Plot
# ***

# %% [markdown]
# ### What is the line plot:
#
#
# Line plot is a type of chart that displays information as a series of data points connected by straight line segments.
#
# Line plots are generally used to visualize the directional movement of one or more data over time. In this case, the X axis would be datetime and the y axis contains the measured quantity.
#
# A line plot is often the first plot of choice to visualize any time series data.[25]
#
#
# **Parameters**
# - x,y: array-like or scalar:
# The horizontal / vertical coordinates of the data points. x values are optional and default to range(len(y)).
# Commonly, these parameters are 1D arrays.They can also be scalars, or two-dimensional (in that case, the columns represent separate data sets).
#
# - fmt: str, optional:
# A format string, e.g. 'ro' for red circles. A format string consists of a part for color, marker and line:fmt = '[marker][line][color]'
#
# - data: indexable object, optional:
# An object with labelled data. If given, provide the label names to plot in x and y.[26]

# %% [markdown]
# **Simple Line Plot**
#
# Let's get stated by plotting a simple line plot. The simple code below uses and array with 4 numbers these will be used for the y-axis. The x-axis range will then be autogenerated by the y length. [27]

# %%
plt.plot([1, 3, 5, 7])
plt.ylabel('Numbers')
plt.show()

# %% [markdown]
# You can plot as many points as you like, just make sure you have the same number of points in both axis.The below plot was not given the x and y parameters directly but will generate the line based on the 2 arrays passed to the function.i.e the first number in each array will be a point.

# %%
#Simple line plot using a 2 arrays 
plt.plot([1,2,3],[2,4,6])

# %% [markdown]
# **Use of Markers/Legends/Fontsize/Type/Legends in Line plots**
#
# Lets define an np array as the ypoints and pass this into the plot function and add a marker to denote the points.
#
# Te second plot is using some of the functions in matplotlib on a basic plot. Looking at fontsize and type and legends,colours.

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'D')
plt.show()

# %%
x= [1,2,3]
y= [2,4,6]
plt.plot(x,y, label='2x', color = 'red', linewidth=2, marker='.', linestyle='--',markersize=12, markeredgecolor='green')
plt.title('Basic Graph on Matplotlib', fontdict={'fontname': 'serif', 'fontsize': 15})
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %% [markdown]
# **Using FMT with Line PLots**

# %%
# lets use shorthand notation for the graph
# fmt ='[color][marker][line]'
x= [1,2,3]
y= [2,4,6]
plt.plot(x,y, 'r^--', label = '2x')
plt.title('Basic Graph on Matplotlib', fontdict={'fontname': 'serif', 'fontsize': 15})
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %% [markdown]
# **Ploting two lines in plt.plot withdifferent linestyles**
#
# Below we have two lines coded to appear on the plot. The second green line has two line styles. The beginning of the line as denoted by [:6] is using the default line style. The second line of code for this green line is as denoted by [5:] (six was not inclusive in the first line) is given the linestyle--.

# %%
# now we will do a second line in the graph using the numpy function 
x= [0,1,2,3,4]
y= [0,2,4,6,8]
#Resize the graph and dpi. Dpi specifies pixels per inch. 
plt.figure(figsize=(7,4), dpi=100)
plt.plot(x,y, 'r^--',label='2x')
#select the interval we want to plot the points at 
x2 = np.arange(0,4.5,0.5)
#plot part of the graph as a line and then the remainder as --
plt.plot(x2[:6], x2[:6]**2, 'g', label='X^2') # the 6 here is exlusive that is why we started at five for the line below
plt.plot(x2[5:], x2[5:]**2, 'g--')

plt.title('Two Line Basic Graph on Matplotlib', fontdict={'fontname': 'serif', 'fontsize': 15})
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.xticks([0,1,2,3,4,])
plt.legend()
#plt.savefig('practicegraph01.png', dpi=100)
plt.show()

# %% [markdown]
# **Formatting the style of your plot**
#
# The matplotlib API reference has a long list of  25 different markers to us in your line plots.[26]

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r8', t, t**2, 'bp', t, t**3, 'gd')
plt.title('Using Different Marker Types')
plt.show()

# %% [markdown]
# **Highlighting Point Markers or Shapes:**
#
# A simple trick to change a particular point marker shape, size is to first plot it with all the other data then plot one more plot only with that point (or set of points if you want to change the style of multiple points). Suppose we want to change the marker shape of second point[28]:

# %%
x = [1,2,3,4,5]
y = [2,1,3,6,7]
plt.plot(x, y, "-o")
x0 = [2]
y0 = [1]
plt.plot(x0, y0, "s")
plt.title('Highlighting Certain Points in the line Plot')
plt.show()

# %% [markdown]
# **Annotating text**
#
# The uses of the basic text function above place text at an arbitrary position on the Axes. A common use for text is to annotate some feature of the plot, and the annotate method provides helper functionality to make annotations easy. In an annotation, there are two points to consider: the location being annotated represented by the argument xy and the location of the text xytext. Both of these arguments are (x, y) tuples.

# %%
ax = plt.subplot()
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)
x0 = [2]
y0 = [1]
plt.plot(x0, y0, "s")

plt.annotate('IMPORTANT ORANGE SQUARE!!!', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='g', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# **Datetime Visualization with Matplotlib lineplot:**
#
# Lineplot is routinely use to plot timeseries data.[29]

# %%
ts = pd.Series(np.random.randn(180), index=pd.date_range('1/1/2021', periods=180))
df = pd.DataFrame(np.random.randn(180, 3), index=ts.index, columns=list('ABC'))
df.cumsum().plot()
plt.show()

# %%
### Working with real world data[28,29]

# %% [markdown]
# **Plotting a lineplot alongside a barchart**
#
# The plot below looks at looking at a timeseries using barplots and line plots to look at all the data in the given sample dataset.

# %%
df = pd.read_csv('Sample_weather.txt',sep = '\t')
df.columns = ['month', 'avg_high','avg_low','record_high','record_low','avg_precipitation']

# %%
plt.figure(figsize=(10,5)) # Plot size
plt.bar(df['month'], df['record_high'], color='r', label='Record High')
plt.bar(df['month'], df['record_low'], color='c', label='Record Low')
plt.plot(df['month'], df['avg_high'], color='k', label= 'Avg High')
plt.plot(df['month'], df['avg_low'], color='b', label = 'Avg Low')
plt.xlabel('Months')
plt.ylabel('Precipitation')
plt.legend()
plt.show()

# %% [markdown]
# **Timeseries data visulaised using lineplot**
#
# I have downloaded a sample dataset which analysed gas prices in serveral countries over a specified time period. I will use the line plot to illustrate easily the data.
#
# The first plot is a simple line plot that plots the gas prices per year in the USA. However because I have not set the line space the years are coming out every 2.5 years which doesnt look great. To fix this to every 2 years plt.xticks(gas.Year[::2]) was used.

# %%
gas = pd.read_csv('data/gas_prices.csv')
plt.plot(gas.Year, gas.USA) # x is year and y axis is gas price
plt.show()

# %% [markdown]
# **Several Countries being Plotted to compare gas prices within region**
#
# The lineplot here is a great tool to use to look at many variables over a specified time period. The code to fix the year on the x axis has been apploed to correct from the period plot.

# %%
plt.figure(figsize=(10,5))
plt.title('Gas prices in US Dollars')

plt.plot(gas.Year, gas.USA, 'b.-',label= 'US') # x is year and y axis is gas price
plt.plot(gas.Year, gas.Canada, 'r^-' ,label= 'Canada')
plt.plot(gas.Year, gas['South Korea'],'g*-' ,label = 'SK') # need to use a list here because of the space in the name in South Korea
plt.plot(gas.Year, gas.France, 'y^-', label ='France')
plt.xlabel('Year')
plt.ylabel('US Dollar')
plt.xticks(gas.Year[::2]) # only want every two years as the figure will be too squashed if we do every year
plt.legend()       
plt.show()

# %% [markdown]
# **Lets Visualize all the countries on the plot:**

# %%
plt.figure(figsize=(10,5))
plt.title('Gas prices in US Dollars', fontdict={'fontweight': 'bold', 'fontsize': 15})

for country in gas:
    if country!= 'Year':
        plt.plot(gas.Year, gas[country], marker = '.', label=country)
plt.xlabel('Year')
plt.ylabel('US Dollar')
plt.xticks(gas.Year[::2]) # only want every two years as the figure will be too squashed if we do every year
plt.legend()       
plt.show()

# %% [markdown]
# **Lets look at specific countries using a for loop:**

# %%
plt.figure(figsize=(10,5))
plt.title('Gas prices in US Dollars',fontdict={'fontweight': 'bold', 'fontsize': 15})
countries_to_look_at =['France','Germany', 'Italy', 'UK']
for country in gas:
    if country in countries_to_look_at:
        plt.plot(gas.Year, gas[country], marker = '.', label=country)
plt.xlabel('Year')
plt.ylabel('US Dollar')
plt.xticks(gas.Year[::2]) # only want every two years as the figure will be too squashed if we do every year
plt.legend()       
plt.show()

# %% [markdown]
# # References
#
# [1][What Is Pyplot In Matplotlib?](https://www.activestate.com/resources/quick-reads/what-is-pyplot-in-matplotlib/#:~:text=Pyplot%20is%20an%20API%20%28Application%20Programming%20Interface%29%20for,in%20the%20form%20of%20plots%2C%20graphs%20and%20charts.)
#
# [2][Please Stop using Pylab](https://nbviewer.org/github/Carreau/posts/blob/master/10-No-PyLab-Thanks.ipynb?create=1)
#
# [3][Matplotlib Tutorial for Data Science](https://thecleverprogrammer.com/2020/06/08/matplotlib-tutorial-for-data-science/)
#
# [4][Matplotlib Pyplot](https://www.machinelearningplus.com/plots/matplotlib-pyplot/)
#
# [5][API Reference](https://matplotlib.org/stable/api/index.html)
#
# [6][Python | Object Oriented Style Plotting in Matplotlib](https://www.includehelp.com/python/object-oriented-style-plotting-in-matplotlib.aspx)
#
# [7][matplotlib.pyplot.scatter() in Python](https://www.geeksforgeeks.org/matplotlib-pyplot-scatter-in-python/)
#
# [8][Matplotlib Scatter Plot Examples](https://www.tutorialkart.com/matplotlib-tutorial/matplotlib-pyplot-scatter/#:~:text=Matplotlib%20Scatter%20Plot%20Example%20The%20definition%20of%20scatter,vmax%3DNone%2C%20alpha%3DNone%2C%20linewidths%3DNone%2C%20%2A%2C%20edgecolors%3DNone%2C%20plotnonfinite%3DFalse%2C%20data%3DNone%2C%20%2A%2Akwargs%29)
#
# [9][How to set Color for Markers in Scatter Plot in Matplotlib?](https://www.tutorialkart.com/matplotlib-tutorial/matplotlib-pyplot-scatter-color/)
#
# [10][Create Scatter plot in Python:](https://www.datasciencemadesimple.com/scatter-plot-in-python-using-matplotlib/)
#
# [11][Python Scatter Plot](https://www.machinelearningplus.com/plots/python-scatter-plot/)
#
# [12][Matplotlib Scatterplot legend for points](https://stackoverflow.com/questions/28171131/matplotlib-scatterplot-legend-for-points)
#
# [13][Matplotlib scatter marker](https://pythonguides.com/matplotlib-scatter-marker/)
#
# [14][What is a Histogram?](https://www.machinelearningplus.com/plots/matplotlib-histogram-python-examples/)
#
# [15][A Complete Guide to Histograms](https://chartio.com/learn/charts/histogram-complete-guide/#:~:text=When%20you%20should%20use%20a%20histogram.%20Histograms%20are,or%20symmetric%2C%20and%20if%20there%20are%20any%20outliers.)
#
# [16][Histogram](https://en.wikipedia.org/wiki/Histogram#Number_of_bins_and_width)
#
# [17][Plotting Histogram in Python using Matplotlib](https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/)
#
# [18][Introduction to matplotlib Bar Charts, Annotation & Histograms with Python](https://www.youtube.com/watch?v=FvW3M6MLMoo)
#
# [19][Introduction to matplotlib Data Visualization for Python](https://alphabench.com/data/python-matplotlib-tutorial.html)
#
# [20][Pyplot Text](https://matplotlib.org/stable/gallery/pyplots/pyplot_text.html#sphx-glr-gallery-pyplots-pyplot-text-py)
#
# [21][Matplotlib - Histograms](https://github.com/Balu-Boda/Matplotlib/blob/master/Matplotlib%20-%20Histograms.ipynb)
#
# [22][Matplotlib Histogram Tutorial](https://github.com/arseniyturin/Matplotlib-Histogram)
#
# [23][matplotlib_histogram_plot](https://github.com/vin1974/matplotlib_histogram_plot)
#
# [24][Histogram Graph: Examples, Types + [Excel Tutorial]](https://www.formpl.us/resources/graph-chart/histogram/#:~:text=The%20case%20is%20quite%20different%20for%20histograms%2C%20which,the%20frequency%20of%20points%20in%20a%20class%20interva)
#
# [25][Matplotlib Line Plot](https://www.machinelearningplus.com/plots/matplotlib-line-plot/)
#
# [26][matplotlib.pyplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot)
#
# [27][Matplotlib Plotting](https://www.w3schools.com/python/matplotlib_plotting.asp)
#
# [28][Set markers for individual points on a line in Matplotlib](https://stackoverflow.com/questions/8409095/set-markers-for-individual-points-on-a-line-in-matplotlib)
#
# [29][Python: Intro to Visualization with Matplotlib](https://www.youtube.com/watch?v=MbKrSmoMads)
#
# [30][Matplotlib Crash Course](https://www.youtube.com/watch?v=3Xc3CA655Y4)

# %% [markdown]
# # End
