# %% [markdown]
# # Overview of Matplotlib.pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
# - Create publication quality plots.
# - Make interactive figures that can zoom, pan, update.
# - Customize visual style and layout.
# - Export to many file formats .
# - Embed in JupyterLab and Graphical User Interfaces.
# - Use a rich array of third-party packages built on Matplotlib.
#
# **Pyplot** is an API (Application Programming Interface) for Python’s matplotlib that effectively makes matplotlib a viable open source alternative to MATLAB. Matplotlib is a library for data visualization, typically in the form of plots, graphs and charts.
#
# Pyplot provides matplotlib with two key features:
#
# [1] A MATLAB-style interface, which allows those familiar with MATLAB to adopt Python more easily
#
# [2] Statefulness, which means that pyplot stores the state of an object when you first plot it. This is essential for use in the same loop or session state until plt.close() is encountered in the code. State can also be important when creating several plots continuously.[1]

# %% [markdown]
# ### Theory behind Matplotlib:
#
# ***

# %% [markdown]
# To understand how matplotlib works we should look at the history of Matplotlib. Matplotlib was originally developed by a neurobiologist named John D. Hunter in the early 2000s.
# His original inspiration for the project came from the popular MATLAB software. He wanted to emulate MATLAB’s plotting commands, but within Python, effectively combining the power of both Python and MATLAB.Unfortunately, John passed away in 2012. But now Matplotlib is a full-fledged community effort developed and maintained by a host of talented individuals.
#
# One area where Matplotlib draws inspiration from MATLAB is in its global import style. The Python concept of importing is not heavily used in MATLAB, meaning that most of MATLAB’s functions are readily available to the user at the top level.These functions can be called on their own, instead of on some object or a module alias. These functions all exist inside of a submodule of matplotlib called pyplot.
#
# One important, big picture Matplotlib concept is its object hierarchy.In Matplotlib, a plot is a hierarchy of nested Python objects. A hierarchy means that there is a tree-like structure of Matplotlib objects underlying each plot.
#
# A Figure object is the outermost container for a Matplotlib plot. The Figure object contain multiple Axes objects. So, the Figure is the final graphic that may contain one or more Axes. The Axes represent an individual plot.
#
# So, we can think of the Figure object as a box-like container containing one or more Axes. The Axes object contain smaller objects such as tick marks, lines, legends, title and text-boxes. The components of a matplotlib figure can be seen below.https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py

# %% [markdown]
# ### Matplotlib API Overview
# #ref: https://thecleverprogrammer.com/2020/06/08/matplotlib-tutorial-for-data-science/#:~:text=There%20is%20an%20Object%20Hierarchy%20within%20Matplotlib.%20In,is%20the%20outermost%20container%20for%20a%20Matplotlib%20plot.
# ***
#
# Matplotlib has two APIs to work with. A MATLAB-style state-based interface and a more powerful object-oriented (OO) interface. The former MATLAB-style state-based interface is called pyplot interface and the latter is called Object-Oriented interface.

# %% [markdown]
# ref https://www.machinelearningplus.com/plots/matplotlib-pyplot/
# ### IMPORTANT PYPLOT COMMANDS YOU MUST KNOW
#
#
# plt.figure() – Set the properties of the figure canvas, like figsize, dpi etc.
#
#
# plt.subplot() – Select the subplot to draw within the figure.
#
# plt.plot() – Makes a line plot by default. Can make other types
#
# plt.subplots() – Create and initialize the figure and axes. This outputs the figure and axis objects.
#
# plt.scatter(x,y) – Draw a scatterplot of x and y
#
# plt.pie() – Create a pie chart
#
# plt.hist() – Create a histogram
#
# plt.hist2d() – Create 2-D Histogram
#
# plt.bar() – Create bar plot
#
# plt.text() – Add text annotation inside the plot
#
# plt.colorbar() – Add a colorbar. Used when color of dots in scatterplot is set based on a continuous numeric variable.
#
# plt.xlabel(), plt.ylabel() – label the x and y axis
#
# plt.xlim(), plt.ylim() – Set X and Y axis limits
#
# plt.title() – Add current plot’s title
#
# plt.legend() – Set the legend for current plot
#
# plt.suptitle() – Apply a title for entire figure
#
# plt.tight_layout() – Tightly arrange the subplots
#
# plt.xticks(), plt.yticks() – Adjust the x and y axis ticks position and labels
#
# plt.gca(), plt.gcf() – Get the current axis and figure
#
# plt.subplot2grid and plt.GridSpec – Lets you draw complex layouts
#
# plt.show() – Display the entire plot
#
# plt.rcParams.update() – Update global plotting parameters

# %% [markdown]
# **Visulaization with Pyplot:**
#
# Generating visualization with Pyplot is very easy. The x-axis values ranges from 0-3 and the y-axis from 1-4. If we provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values.
#
# Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0,1,2,3] and y data are [1,2,3,4]. See code below for plot generated

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('Numbers')
plt.show()

# %% [markdown]
# **State-machine interface:**
#
# Pyplot provides the state-machine interface to the underlying object-oriented plotting library. The state-machine implicitly and automatically creates figures and axes to achieve the desired plot. For example:

# %%
x = np.linspace(0, 5, 50)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %% [markdown]
# **Formatting the style of plot**
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot. The letters and symbols of the format string are from MATLAB.
# We can concatenate a color string with a line style string. The default format string is ‘b-‘, which is a solid blue line. For example, to plot the above line with blue asterics, we would issue the code below.The axis() command below takes a list of [xmin, xmax, ymin, ymax] and specifies the viewport of the axes.

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'b*')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# **Object-Oriented API**
# Creating axes and figures explicitly by initializing objects for a figure. We can call methods on them and therefore it is called as object-oriented (OO) style.
#
# The Object-Oriented API is available for more complex plotting situations. It allows us to exercise more control over the figure.
#
# In Pyplot API, we depend on some notion of an “active” figure or axes. But, in the Object-Oriented API the plotting functions are methods of explicit Figure and Axes objects.
#
# Figure is the top level container for all the plot elements. We can think of the Figure object as a box-like container containing one or more Axes.
#
# The Axes represent an individual plot. The Axes object contain smaller objects such as axis, tick marks, lines, legends, title and text-boxes.

# %%
#Python for code object-oriented style plotting vrs pyplot in matplotlib

# %%
#https://www.includehelp.com/python/object-oriented-style-plotting-in-matplotlib.aspx
x = np.linspace(0, 2, 20)

fig, ax = plt.subplots()  
ax.plot(x, x, label='linear')  
ax.plot(x, x**2, label='quadratic')  
ax.step(x, x**3, label='cubic steps')  
ax.set_xlabel('x label')  
ax.set_ylabel('y label')  
ax.set_title("A simple plot using Object Oriented Style")  
ax.legend()  
ax.grid()

plt.figure()
plt.plot(x, x, label='linear')  
plt.plot(x, x**2, label='quadratic')  
plt.step(x, x**3, label='cubic steps')  
plt.xlabel('x label')  
plt.ylabel('y label')  
plt.title("A simple plot using automatically created by pyplot")  
plt.legend()  
plt.grid()

# %% [markdown]
# An in-depth explanation of three interesting plots from the matplotlib.pyplot
# Python package is required for this notebook. The three plots we will be looking at in detail are
#
# - the scatter plot
# - the histogram plot
# - the line plot

# %% [markdown]
# # The Scatter Plot in the matplotlib.pyplot package
#
# ***
#
# Scatter plots are used to observe relationship between variables and uses dots to represent the relationship between them. The scatter() method in the matplotlib library is used to draw a scatter plot. Scatter plots are widely used to represent relation among variables and how change in one affects the other.
#
# The scatter() method takes in the following parameters:
# - x_axis_data- An array containing x-axis data
# - y_axis_data- An array containing y-axis data
# - s- marker size (can be scalar or array of size equal to size of x or y)
# - c- color of sequence of colors for markers
# - marker- marker style
# - cmap- cmap name
# - linewidths- width of marker border
# - edgecolor- marker border color
# - alpha- blending value, between 0 (transparent) and 1 (opaque)
# - Except x_axis_data and y_axis_data all other parameters are optional and their default value is None
#
# The definition of scatter plot with all the parameters is:
#
# scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, *, edgecolors=None, plotnonfinite=False, data=None, **kwargs)
#
# ref: https://www.geeksforgeeks.org/matplotlib-pyplot-scatter-in-python/#:~:text=Scatter%20plots%20are%20used%20to%20observe%20relationship%20between,and%20how%20change%20in%20one%20affects%20the%20other.

# %% [markdown]
# Let's start with a a scatteR plot using minimum code.
#
# You perform the following steps:
#
# - Import the matplotlib module.
# - Create the data for the (x,y) points.
# - Plot the data using the plt.plot() function. The first argument is the iterable of x values. The second argument is the iterable of y values. The third argument is the style of the scatter points. If the style had not been included in the first figure code 'o' this code would have drawn a lineplot.
# - The second scatter plot below uses the same x and y variables but instead of using *plt.plt* I used *plt.scatter* and denoted the colour to use in the figure.

# %%
x = [0, 1, 2, 3, 4, 5]
y = [1, 2, 4, 8, 16, 32]
plt.plot(x, y,'o') 
plt.show()

# %%
x = [0, 1, 2, 3, 4, 5]
y = [1, 2, 4, 8, 16, 32]
plt.scatter(x, y, c='blue')
plt.show()

# %% [markdown]
# Now lets create a scatterplot that will use some more functions in the package such as labels,figsize,titles and legends.
#
#
# Now, let us specify size to each of the points. To specify size to each of the markers, pass a list for named parameter s to scatter() function. Respective values from the s size list shall be applied to the markers drawn at points specified by x and y.
#
# In the following example, the size for markers is generated randomly using numpy.random. 25 values are generated for size, in the range (0, 25).We can set color to each of the marker in the scatter plot. Provide the list of colors as fourth parameter or named parameter c for scatter() function.

# %%
#ref:https://www.tutorialkart.com/matplotlib-tutorial/matplotlib-pyplot-scatter/#:~:text=Matplotlib%20Scatter%20Plot%20Example%20The%20definition%20of%20scatter,vmax%3DNone%2C%20alpha%3DNone%2C%20linewidths%3DNone%2C%20%2A%2C%20edgecolors%3DNone%2C%20plotnonfinite%3DFalse%2C%20data%3DNone%2C%20%2A%2Akwargs%29
#ref https://www.tutorialkart.com/matplotlib-tutorial/matplotlib-pyplot-scatter-color/
from numpy.random import default_rng
rng = default_rng(12345)

x = rng.integers(0, 25, 25)
y = rng.integers(0, 25, 25)
#size
size = rng.integers(0, 25, 25)
color= rng.integers(0,25,25) 
fig, ax = plt.subplots()

#scatter plot
scatter = ax.scatter(x, y, c=color, s=size)
#plt.scatter(x, y, s = size, c= color)
# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Colours")
ax.add_artist(legend1)
# produce a legend with a cross section of sizes from the scatter
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
legend2 = ax.legend(handles, labels, loc="upper right", title="Sizes")

plt.show()

# %% [markdown]
# Scatterplots are used to observe relationships between two different variable so lets check this out with some sample data. #REFhttps://github.com/aldrinbrillante/scatterplot_grades/blob/main/Scatterplot%20Activity%201.ipynb. This scatter plot will llok at the relationship between apples eaten per day and trips to the doctor per year using numpy for the arrays. As we can see from the scatterplt below it appears that the the more apples you eat the less visits you need to pay the doctor.

# %%
# Number of apples eaten per day (no-unit)
X = np.array([0,2,4,0,3,2,0])

# Doctors Visits per year
Y = np.array([4,1,0,3,1,1,5])

plt.scatter(X, Y)
plt.xlabel('Apples Daten Daily')
plt.ylabel('Doctors Visits Yearly')
plt.show()

# %% [markdown]
# Lets look at a scatter plot with three different data groups with height and  weight measured. Each group is differenciated using the diffrernt colours.

# %%
#ref https://www.datasciencemadesimple.com/scatter-plot-in-python-using-matplotlib/
weight1=[57,58.2,58.6,59.6,59.8,60.2,60.5,60.6,60.7,61.3,61.3,61.4,61.8,61.9,62.3]
height1=[100.7,195.6,94.3,127.1,111.7,159.7,135,149.9,124.3,112.9,176.7,110.2,123.9,161.9,107.8]

weight2=[62.9,63,63.1,63.2,63.3,63.4,63.4,63.4,63.5,63.6,63.7,64.1,64.3,64.3,64.7,64.8,65]
height2=[151.8,156.3,136.1,124.2,156.3,130,181.2,255.9,163.1,123.1,119.5,179.9,114.8,174.1,108.8,105.4,141.4]

weight3=[69.2,69.2,69.4,69.7,70,70.3,70.8,71,71.1,71.7,71.9,72.4,73,73.1,76.2]
height3=[166.8,172.9,193.8,137.4,162.4,137.1,169.1,237.1,189.1,179.3,174.8,213.3,198,191.1,220.6]

weight=np.concatenate((weight1,weight2,weight3))
height=np.concatenate((height1,height2,height3))

color_array = ['b'] * 15 + ['g'] * 17 + ['r']*15

plt.scatter(weight, height, marker=r'$\clubsuit$', c=color_array)

plt.xlabel('weight', fontsize=16)

plt.ylabel('height', fontsize=16)

plt.title('grouped scatter plot - height vs weight',fontsize=20)

plt.show()

# %%
#https://www.machinelearningplus.com/plots/subplots-python-matplotlib/
# Create data
N = 50
g1 = (0.5 + 0.6 * rng.random(N), rng.random(N))
g2 = (0.4+0.3 * rng.random(N), 0.5*rng.random(N))
g3 = (0.4*rng.random(N),0.3*rng.random(N))

data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water")

# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, facecolor="1.0")

for data, color, group in zip(data, colors, groups):
    x, y = data
ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)

plt.title('Matplot scatter plot')
plt.legend(loc=2)
plt.show()

# %%
#https://stackoverflow.com/questions/44970881/matplotlib-multiple-scatter-subplots-with-shared-colour-bar
def getRand(n):
    return np.random.normal(scale=10, size=n)

f = plt.figure()    
f, axes = plt.subplots(nrows = 2, ncols = 2, sharex=True, sharey = True)
norm=plt.Normalize(-22,22)
sc = axes[0][0].scatter(getRand(100),getRand(100), c = getRand(100), marker = "x", norm=norm)
axes[0][0].set_xlabel('Crosses', labelpad = 5)

axes[0][1].scatter(getRand(100),getRand(100), c = getRand(100), marker = 'o', norm=norm)
axes[0][1].set_xlabel('Circles', labelpad = 5)

axes[1][0].scatter(getRand(100),getRand(100), c = getRand(100), marker = '*', norm=norm)
axes[1][0].set_xlabel('Stars')

axes[1][1].scatter(getRand(100),getRand(100), c = getRand(100), marker = 's', norm=norm )
axes[1][1].set_xlabel('Squares')

cbar_ax = f.add_axes([0.85, 0.15, 0.05, 0.7])

f.colorbar(sc, cax=cbar_ax)

plt.show()

# %%
#https://stackoverflow.com/questions/28171131/matplotlib-scatterplot-legend-for-points
# %matplotlib inline
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, facecolor="1.0")

g1 = ([1,2,3], [4,2,3])
g2 = ([4,5,6], [4,5,6])
g3 = ([7,8,9,10], [7,8,9,10])
data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("monkey", "whale", "cat") 

for data, color, group in zip(data, colors, groups):
    x, y = data
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)
plt.legend(loc=2)

# %% [markdown]
# #https://www.machinelearningplus.com/plots/python-scatter-plot/
# If you want the color of the points to vary depending on the value of Y (or another variable of same size), specify the color each dot should take using the c argument.
# You can also provide different variable of same size as X.

# %%
#https://www.machinelearningplus.com/plots/python-scatter-plot/
# Simple Scatterplot with colored points
x = range(50)
y = range(50) + np.random.randint(0,30,50)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.scatter(x, y, c=y, cmap='Spectral')
plt.colorbar()
plt.title('Simple Scatter plot')
plt.xlabel('X - value')
plt.ylabel('Y - value')
plt.show()

# %% [markdown]
# Create a dataset with exponentially increasing relation and visualize the plot.

# %% [markdown]
# #create a dataset with exponentially increasing relation and visualize the plot.
# np.arrange(lower_limit, upper_limit, interval) is used to create a dataset between the lower limit and upper limit with a step of ‘interval’ no. of points.
# Now you can see that there is a exponential relation between the x and y axis.

# %%
# Scatterplot of non-random variables
x=np.arange(1,10,0.2)
y= np.exp(x)
plt.scatter(x,y)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Exponential Relation dataset')
plt.show()

# %% [markdown]
# ### Correlation with Scatter plot
# 1) If the value of y increases with the value of x, then we can say that the variables have a positive correlation.
#
# 2) If the value of y decreases with the value of x, then we can say that the variables have a negative correlation.
#
# 3) If the value of y changes randomly independent of x, then it is said to have a zero corelation.
#
# In the below graph, you can see that the blue line shows an positive correlation, the orange line shows a negative corealtion and the green dots show no relation with the x values(it changes randomly independently).

# %%
# Scatterplot and Correlations
# Data
x=np.random.randn(100)
y1= x*5 +9 
y2= -5*x
y3=np.random.randn(100)

# Plot
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.scatter(x, y1, label=f'y1 Correlation = {np.round(np.corrcoef(x,y1)[0,1], 2)}')
plt.scatter(x, y2, label=f'y2 Correlation = {np.round(np.corrcoef(x,y2)[0,1], 2)}')
plt.scatter(x, y3, label=f'y3 Correlation = {np.round(np.corrcoef(x,y3)[0,1], 2)}')

# Plot
plt.title('Scatterplot and Correlations')
plt.legend()
plt.show()

# %% [markdown]
# ### Changing the Color and Marker
# Use the marker =_____ command to change the marker type in scatter plot.
#
# [‘.’,’o’,’v’,’^’,’>’,'<‘,’s’,’p’,’*’,’h’,’H’,’D’,’d’,’1′,”,”] – These are the types of markers that you can use for your plot.

# %%
#*Scatterplot of different distributions. Color and Shape of Points.*
x = np.random.randn(500)
y1 = np.random.randn(500)
y2 = np.random.chisquare(10, 500)
y3 = np.random.poisson(5, 500)

#*Plot*
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.scatter(x,y1,color='blue', marker= '*', label='Standard Normal')
plt.scatter(x,y2,color= 'red', marker='v', label='Chi-Square')
plt.scatter(x,y3,color= 'green', marker='.', label='Poisson')


#*Decorate*
plt.title('Distributions: Color and Shape change')
plt.xlabel('X - value')
plt.ylabel('Y - value')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Plotting with keyword strings**
#
#
# There are some instances where you have data in a format that lets you access particular variables with strings. For example, with numpy.recarray or pandas.DataFrame.
#
# Matplotlib allows you provide such an object with the data keyword argument. If provided, then you may generate plots with the strings corresponding to these variables.

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# Scatter Plot with Linear fit plot using Seaborn
# Lets try to fit the dataset for the best fitting line using the lmplot() function in seaborn.
#
# Lets use the mtcars dataset.
#
# You can download the dataset from the given address: https://www.kaggle.com/ruiromanini/mtcars/download
#
# Now lets try whether there is a linear fit between the mpg and the displ column .
#
# You can see that we are getting a negative corelation between the 2 columns.

# %%
# Linear - Line of best fit
import seaborn as sns
url = 'https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv'
df=pd.read_csv(url)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
sns.lmplot(x='mpg', y='disp', data=df)
plt.title("Scatter Plot with Linear fit")
# Out:
# Text(0.5, 1.0, 'Scatter Plot with Linear fit')

# %% [markdown]
# # The Histogram  Plot in the matplotlib.pyplot package
#
# ***

# %%
#refhttps://www.machinelearningplus.com/plots/matplotlib-histogram-python-examples/

# %% [markdown]
# ref: https://chartio.com/learn/charts/histogram-complete-guide/#:~:text=When%20you%20should%20use%20a%20histogram.%20Histograms%20are,or%20symmetric%2C%20and%20if%20there%20are%20any%20outliers.
# ### What is a histogram?
# A histogram is a chart that plots the distribution of a numeric variable’s values as a series of bars. Each bar typically covers a range of numeric values called a bin or class; a bar’s height indicates the frequency of data points with a value within the corresponding bin.
#
# Histograms are good for showing general distributional features of dataset variables. You can see roughly where the peaks of the distribution are, whether the distribution is skewed or symmetric, and if there are any outliers.
#
# *Common misuses*
#
# Measured variable is not continuous numeric:
# As noted in the opening sections, a histogram is meant to depict the frequency distribution of a continuous numeric variable. When our variable of interest does not fit this property, we need to use a different chart type instead: a bar chart. A variable that takes categorical values, like user type (e.g. guest, user) or location are clearly non-numeric, and so should use a bar chart. However, there are certain variable types that can be trickier to classify: those that take on discrete numeric values and those that take on time-based values.
#
# Histogram Distributions
# ref;https://www.pluscharts.com/histogram-and-their-uses/

# %% [markdown]
# ### Basic Histogram Plotting in Matplotlib

# %% [markdown]
# The following list shows the parameters accepted by matplotlib.pyplot.hist() function :
# ref:https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/
#
# **Attribute parameter**
#
# - x-array or sequence of array
#
# - bins-optional parameter contains integer or sequence or strings
#
# - density-optional parameter contains boolean values
#
# - range-optional parameter represents upper and lower range of bins
#
# - histtype-optional parameter used to create type of histogram [bar, barstacked, step, stepfilled], default is “bar”
#
# - align-optional parameter controls the plotting of histogram [left, right, mid]
#
# - weights-optional parameter contains array of weights having same dimensions as x
#
# - bottom-location of the basline of each bin
#
# - rwidth- optional parameter which is relative width of the bars with respect to bin width
#
# - color-optional parameter used to set color or sequence of color specs
#
# - label-optional parameter string or sequence of string to match with multiple datasets
#
# - log-optional parameter used to set histogram axis on log scale

# %% [markdown]
# Let's start with some basic histogram plotting in the matplotlib.pyplot library
#
# An array is created using numpy and assigned it to x. We are then drawing a python histogram using the hist function without any bins argument.

# %%
# Creating dataset
x = np.array([4,7,9,34,5,67,85,32,4,5,21,7])
 
# Creating histogram
plt.hist(x)

plt.show()

# %% [markdown]
# Lets plot the same numpy array and use the bin function. It means the whole Quantity data distributed into twenty bins. If the bins argument  is not used the hist function will automatically create and used default bins. In the below code I used the bins number explicitly by assigning 20 and the data will equally distribute into 20 bins.

# %%
# Creating dataset
x = np.array([4,7,9,34,5,67,85,32,4,5,21,7])
 
# 
plt.hist(x, bins=20)

plt.show()

# %% [markdown]
# Now we can create some histogram plots using the numpy random function to generate some datasets

# %%
#https://www.youtube.com/watch?v=FvW3M6MLMoo
#https://alphabench.com/data/python-matplotlib-tutorial.html
from numpy.random import default_rng # import default PC6G4 
rng= default_rng(12345)
mu, sigma = 0, 0.1
mu1,sigma1= 0.3,0.1
s = np.random.default_rng().normal(mu, sigma, 10000)
t = np.random.default_rng().normal(mu1, sigma1, 10000)
count, bins, ignored = plt.hist(s, 30,color='g',edgecolor='w', density=True, alpha=0.8)
count, bins, ignored = plt.hist(t, 30,color='y',edgecolor='w', density=True, alpha=0.5)# using the alpha will create the shawdow in the overlay
plt.grid(axis='y',alpha=0.4)# alpha will amke the gridlines more transparent

# %%
from scipy.stats import norm
plt.hist(s, bins=25,density=True,color='g', edgecolor='w',alpha=0.7)
overlay=np.linspace(x.min(),x.max(),100)
mean,std = norm.fit(s)
pdf=norm.pdf(overlay,mean,std)
plt.xlim(-0.4,0.4)
plt.plot(overlay,pdf,'b--')
plt.text(-0.35,3.0, 'Mean:{:.5f}\nSTD:{:.5f}'. format(mean,std))
# Out:
# Text(-0.35, 3.0, 'Mean:0.00006\nSTD:0.10013')

# %%
age_groups = {'D0-5H':5.0,'D5-14H':3.0,'D15-24H':2.0,'D25-34H':7.0,'D35-44H':8.0,'D45-54H':15.0,'D55-64H':20.0,'D65-74H':25.0,'D75-84H':10.0,'D85upH':5.0}

# %%
sum(age_groups.values())
# Out:
# 100.0

# %%
plt.title('Age Group Percentages',fontsize=18)
plt.grid(axis='y',alpha=0.5)
plt.bar(age_groups.keys(),age_groups.values())
for k,v in age_groups.items():
    plt.text(k,v-2, str(v), fontsize=12
             ,fontweight='bold',
             color='w', horizontalalignment='center')

# %%
plt.title('Age Goup Percentages',fontsize=18)
plt.grid(axis='y',alpha=0.5)
plt.barh(list(age_groups.keys()),list(age_groups.values()))
for k,v in age_groups.items():
    plt.text(v-4,k, str(v), fontsize=12
             ,fontweight='bold',
             color='w', verticalalignment='center')

# %%
#create a dataset code adapted from https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/
from numpy.random import default_rng # import default PC6G4 
rng= default_rng(12345)
# Creating dataset
N_points = 2000
n_bins = 30
 
# Creating distribution
x = rng.random(N_points)
y = .8 ** x + rng.random(2000) + 25
 
# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)
 
axs.hist(x, bins = n_bins)
 
# Show plot
plt.show()

# %% [markdown]
# Now lets plot two histograms side by side to see how they look. One will be a rng random distribution of numbers and the other will be a rng normal distribution.

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.subplot(1,2,1)
x = rng.random(size =2000)
y = rng.normal(size=2000)
plt.hist(x , bins=100) 
plt.subplot(1,2,2) 
plt.hist(y, bins=100) 
plt.tight_layout() 
plt.show()

# %%
#ref https://stackoverflow.com/questions/45069828/how-to-plot-2-histograms-side-by-side
dflux = pd.DataFrame(dict(rate=np.random.randn(10000)))
dflux2 = pd.DataFrame(dict(rate=np.random.randn(10000)))

fig, axes = plt.subplots(1, 2)

dflux.hist('rate', bins=100, ax=axes[0])
dflux2.hist('rate', bins=100, ax=axes[1])
# Out:
# array([<AxesSubplot:title={'center':'rate'}>], dtype=object)

# %% [markdown]
# **The histogram (hist) function with multiple data sets code adapted from https://matplotlib.org/stable/gallery/statistics/histogram_multihist.html
#
# **Plot histogram with multiple sample sets and demonstrate**
#
# Use of legend with multiple sample sets
#
# Stacked bars
#
# Step curve with no fill
#
# Data sets of different sample sizes
#
# Selecting different bin counts and sizes can significantly affect the shape of a histogram. The Astropy docs have a great section on how to select these parameters: http://docs.astropy.org/en/stable/visualization/histogram.html

# %%
np.random.seed(19680801)

n_bins = 10
x = np.random.randn(1000, 3)

fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(nrows=2, ncols=2)

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, density=True, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, density=True, histtype='bar', stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show()

# %% [markdown]
# Using text in our histograms

# %%
# code adapted from https://matplotlib.org/stable/gallery/pyplots/pyplot_text.html#sphx-glr-gallery-pyplots-pyplot-text-py
# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.xlim(40, 160)
plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %%
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.htmlref:

counts, bins = np.histogram(data)
plt.hist(bins[:-1], bins, weights=counts)
# Out:
# (array([2., 0., 0., 2., 0., 0., 2., 0., 0., 2.]),
#  array([ 7. ,  7.3,  7.6,  7.9,  8.2,  8.5,  8.8,  9.1,  9.4,  9.7, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
# dataset sourced from github #https://datagy.io/histogram-python/
df = pd.read_excel('https://github.com/datagy/Intro-to-Python/raw/master/sportsdata.xls', usecols=['Age'])
x = df

# %%
plt.hist(x, bins=50)
plt.gca().set(title='Frequency Histogram', ylabel='Frequency');

# %%
x.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
#code adapted from https://github.com/Balu-Boda/Matplotlib/blob/master/Matplotlib%20-%20Histograms.ipynb
bmi_men=[31,18,40,15,18,19,26,28,21,22,23]
bmi_women=[17,41,30,19,24,21,16,40,35,19,18]

plt.xlabel("Total no of patients")
plt.ylabel("BMI Range")
plt.title("BMI analysis")

plt.hist([bmi_men,bmi_women],bins=10,rwidth=0.95,
         color=["green","orange"],label=["men","women"],orientation="horizontal"
        )
plt.legend()

# %%
#code adapted from https://github.com/arseniyturin/Matplotlib-Histogram/blob/master/histogram.ipynb
y = np.random.normal(0, 1, 3000)
plt.figure(figsize=(10,5)) # Plot size
plt.style.use('seaborn-whitegrid') # Style

# Building a histogram
n, bins, patches = plt.hist(y, bins=90, facecolor='#2ab0ff', edgecolor='#e0e0e0', linewidth=0.5, alpha=0.7)

# Changing properties of each bin
n = n.astype('int') # n should be integer, otherwise it wouldn't work properly

# Accessing each bin, changing color according to height
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))
    
# Pick one bin
patches[40].set_fc('red') # Color
patches[40].set_alpha(1) # Opacity

# Making annotation
plt.annotate('Something important here!', xy=(-0.35, 40), xytext=(2, 130), fontsize=10, arrowprops={'width':0.4,'headwidth':7,'color':'#333333'})

# Adding title and labels with custom font sizes
plt.title('Normal Distribution', fontsize=12)
plt.xlabel('Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.show()

# %%
#https://github.com/vin1974/matplotlib_histogram_plot/blob/main/matplotlib_histogram_test.ipynb

# %%
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]
bins = [i*8 for i in range(1,15)]
median_age = 29
color = 'r'
plt.axvline(median_age, color=color, label='Age Median')
plt.hist(ages, bins=bins, edgecolor='g')
#plt.annotate('Median Age', xy=(0.5, 5), xytext=(2, 8), fontsize=10, arrowprops={'width':0.4,'headwidth':7,'color':'#333333'})
plt.title('Ages Histogram')
plt.xlabel('Ages')
#plt.tight_layout()
plt.show()

# %% [markdown]
# #https://www.formpl.us/resources/graph-chart/histogram/#:~:text=The%20case%20is%20quite%20different%20for%20histograms%2C%20which,the%20frequency%20of%20points%20in%20a%20class%20interval.
# A histogram graph is a graph that is used to visualize the frequency of discrete and continuous data using rectangular bars. The rectangular bars show the number of data points that fall into a specified class interval.
#
# Also known as a histogram chart, the class intervals (or bins) are not always of equal size across the horizontal axis. When constructing a histogram chart, the first thing to do after data collection is to determine the bins or class intervals.
#
# The data should be grouped according to this interval, then a frequency of the data that fall into these groups will be taken. Since the class intervals are usually a continuous range of values, unlike bar charts, the rectangular pars are not spaced (i.e. they touch each other).
#
# Uses of Histogram Graph:
# - Identification of Mode in a Dataset
# Without complex mathematical computations, one can easily identify the most common process outcome in a dataset. By visualizing the collected data on a histogram chart, the outcome with the highest frequency will easily stand out as the peak of the graph.
#
# - Identifying data structure
# One can easily spot trends in the data when reading a histogram chart. This can be helpful in making predictions, optimizing processes, and identifying possible issues.
#
# - Spotting deviations in data
# You can easily spot deviations in data when visualizing using a histogram compared to some other data visualization methods. This is very useful in cases where you are collecting data over time.
#
# Immediately there is a deviation in the data, the deviation is noticed on the histogram chart. This will easily help you let you inspect the data collection process and make amends if the deviation is caused by human error.
#
# Disadvantages of a Histogram Graph
# - It can only be used to visualize continuous data. Since the graphs are usually joined together, it will be incorrect to use a histogram to visualize discrete data. This can only be done using a bar chart.
#
# - Since data is grouped into different categories, histograms cannot read exact values. You cannot identify specific data points in the graph by merely reading the histogram chart.

# %% [markdown]
# # The Line Plot
# ***
#
#
# #ref https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot
#
#
# **Parameters**
# - x,y: array-like or scalar
#
# The horizontal / vertical coordinates of the data points. x values are optional and default to range(len(y)).
#
# Commonly, these parameters are 1D arrays.
#
# They can also be scalars, or two-dimensional (in that case, the columns represent separate data sets).
#
# These arguments cannot be passed as keywords.
#
# - fmt: str, optional
# A format string, e.g. 'ro' for red circles. A format string consists of a part for color, marker and line:A format string consists of a part for color, marker and line:
#
# Format strings are just an abbreviation for quickly setting basic line properties. All of these and more can also be controlled by keyword arguments.
#
# This argument cannot be passed as keyword.
#
# - data: indexable object, optional
#
# An object with labelled data. If given, provide the label names to plot in x and y.
#
# - Returns
# list of Line2D
#
# A list of lines representing the plotted data.
#
# - Other Parameters
# scalex, scaleybool, default: True
#
# These parameters determine if the view limits are adapted to the data limits. The values are passed on to autoscale_view.
#
# - **kwargsLine2D properties, optional
# kwargs are used to specify properties like a line label (for auto legends), linewidth, antialiasing, marker face color.

# %% [markdown]
# Let's get stated by plotting a simple line plot # https://www.youtube.com/watch?v=3Xc3CA655Y4

# %%
plt.plot([1, 3, 5, 7])
plt.ylabel('Numbers')
plt.show()

# %%
#[(https://www.w3schools.com/python/matplotlib_plotting.asp)

# %%
#Simple line plot using a 2 arrays 
plt.plot([1,2,3],[2,4,6])

# %%
# Lets define an np array as the ypoints and pass this into the plot function and add a marker to denote the points
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'D')
plt.show()

# %%
# working with some of the functions in matplotlib on a basic plot. Looking at fontsize and type and legends,colours.
x= [1,2,3]
y= [2,4,6]

plt.plot(x,y, label='2x', color = 'red', linewidth=2, marker='.', linestyle='--',markersize=12, markeredgecolor='green')

plt.title('Basic Graph on Matplotlib', fontdict={'fontname': 'serif', 'fontsize': 15})
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %%
# lets use shorthand notation for the graph
# fmt ='[color][marker][line]'

x= [1,2,3]
y= [2,4,6]

#plt.plot(x,y, label='2x', color = 'red', linewidth=2, marker='.', linestyle='--',markersize=12, markeredgecolor='green')
plt.plot(x,y, 'r^--', label = '2x')
plt.title('Basic Graph on Matplotlib', fontdict={'fontname': 'serif', 'fontsize': 15})
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.show()

# %%
# now we will do a second line in the graph using the numpy function 

x= [0,1,2,3,4]
y= [0,2,4,6,8]
#Resize the graph and dpi. Dpi specifies pixels per inch. 
plt.figure(figsize=(7,4), dpi=100)
#plt.plot(x,y, label='2x', color = 'red', linewidth=2, marker='.', linestyle='--',markersize=12, markeredgecolor='green')
plt.plot(x,y, 'r^--',label='2x')

#select the interval we want to plot the points at 
x2 = np.arange(0,4.5,0.5)
#plot part of the graph as a line and then the remainder as --
plt.plot(x2[:6], x2[:6]**2, 'g', label='X^2') # the 6 here is exlusive that is why we started at five for the line below
plt.plot(x2[5:], x2[5:]**2, 'g--')

plt.title('Basic Graph on Matplotlib', fontdict={'fontname': 'serif', 'fontsize': 15})
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.xticks([0,1,2,3,4,])
plt.legend()
plt.savefig('practicegraph01.png', dpi=100)
plt.show()

# %% [markdown]
# **Formatting the style of your plot**
#
# The matplotlib API reference has a list of different markers to us in your line plots.
# ref:https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# A simple trick to change a particular point marker shape, size... is to first plot it with all the other data then plot one more plot only with that point (or set of points if you want to change the style of multiple points). Suppose we want to change the marker shape of second point:
# REF: https://stackoverflow.com/questions/8409095/set-markers-for-individual-points-on-a-line-in-matplotlib

# %%
x = [1,2,3,4,5]
y = [2,1,3,6,7]

plt.plot(x, y, "-o")
x0 = [2]
y0 = [1]
plt.plot(x0, y0, "s")

plt.show()

# %% [markdown]
# **Annotating text**
#
# The uses of the basic text function above place text at an arbitrary position on the Axes. A common use for text is to annotate some feature of the plot, and the annotate method provides helper functionality to make annotations easy. In an annotation, there are two points to consider: the location being annotated represented by the argument xy and the location of the text xytext. Both of these arguments are (x, y) tuples.

# %%
ax = plt.subplot()

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)
x0 = [2]
y0 = [1]
plt.plot(x0, y0, "s")

plt.annotate('IMPORTANT POINT', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='g', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# Datetime Visualization with Matplotlib lineplot:
# ref: https://www.youtube.com/watch?v=MbKrSmoMads

# %%
ts = pd.Series(np.random.randn(180), index=pd.date_range('1/1/2021', periods=180))
df = pd.DataFrame(np.random.randn(180, 3), index=ts.index, columns=list('ABC'))
df.cumsum().plot()
plt.show()

# %% [markdown]
# ### Working with real world data
# Data downloaded from a github tutorial account
# ref: https://raw.githubusercontent.com/KeithGalli/matplotlib_tutorial/master/gas_prices.csv

# %%
gas = pd.read_csv('data/gas_prices.csv')
gas

# %%
plt.plot(gas.Year, gas.USA) # x is year and y axis is gas price
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Gas prices in US Dollars')

plt.plot(gas.Year, gas.USA, 'b.-',label= 'US') # x is year and y axis is gas price
plt.plot(gas.Year, gas.Canada, 'r^-' ,label= 'Canada')
plt.plot(gas.Year, gas['South Korea'],'g*-' ,label = 'SK') # need to use a list here because of the space in the name in South Korea
plt.plot(gas.Year, gas.France, 'y^-', label ='France')
plt.xlabel('Year')
plt.ylabel('US Dollar')
plt.xticks(gas.Year[::2]) # only want every two years as the figure will be too squashed if we do every year
plt.legend()       
plt.show()

# %% [markdown]
# **Lets Visualize all the countries on the plot:**

# %%
plt.figure(figsize=(10,5))
plt.title('Gas prices in US Dollars', fontdict={'fontweight': 'bold', 'fontsize': 15})

for country in gas:
    if country!= 'Year':
        plt.plot(gas.Year, gas[country], marker = '.', label=country)
plt.xlabel('Year')
plt.ylabel('US Dollar')
plt.xticks(gas.Year[::2]) # only want every two years as the figure will be too squashed if we do every year
plt.legend()       
plt.show()

# %% [markdown]
# **Lets look at specific countries using a for loop:**

# %%
plt.figure(figsize=(10,5))
plt.title('Gas prices in US Dollars',fontdict={'fontweight': 'bold', 'fontsize': 15})
countries_to_look_at =['France','Germany', 'Italy', 'UK']
for country in gas:
    if country in countries_to_look_at:
        plt.plot(gas.Year, gas[country], marker = '.', label=country)
plt.xlabel('Year')
plt.ylabel('US Dollar')
plt.xticks(gas.Year[::2]) # only want every two years as the figure will be too squashed if we do every year
plt.legend()       
plt.show()

# %%
#ref:https://www.geeksforgeeks.org/introduction-to-3d-plotting-with-matplotlib/?ref=rp
# importing mplot3d from
# mpl_toolkits
from mpl_toolkits import mplot3d
 
# creating an empty canvas
fig = plt.figure()
 
# defining the axes with the projection
# as 3D so as to plot 3D graphs
ax = plt.axes(projection="3d")

#Using 3D in a line plot
# creating a wide range of points x,y,z
x=[0,1,2,3,4,5,6]
y=[0,1,4,9,16,25,36]
z=[0,1,4,9,16,25,36]
 
# plotting a 3D line graph with X-coordinate,
# Y-coordinate and Z-coordinate respectively
ax.plot3D(x, y, z, 'red')
 
# plotting a scatter plot with X-coordinate,
# Y-coordinate and Z-coordinate respectively
# and defining the points color as cividis
# and defining c as z which basically is a
# defination of 2D array in which rows are RGB
#or RGBA
ax.scatter3D(x, y, z, c=z, cmap='cividis');
 
# Showing the above plot
plt.show()

# %% [markdown]
# The list of arrays that we created above is the only required input for creating the boxplot. Using the data_to_plot line of code, we can create the boxplot with the following code −

# %% [markdown]
# ### References
#
# [1](https://www.activestate.com/resources/quick-reads/what-is-pyplot-in-matplotlib/#:~:text=Pyplot%20is%20an%20API%20%28Application%20Programming%20Interface%29%20for,in%20the%20form%20of%20plots%2C%20graphs%20and%20charts.)
# [2](https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py)
#
# [5](https://www.tutorialspoint.com/matplotlib/matplotlib_box_plot.htm)
#
# https://github.com/croach/oreilly-matplotlib-course/blob/master/02%20-%20First%20Steps/0205%20-%20The%20Interfaces%20of%20matplotlib.ipynb
